# %% [markdown]
# ## Streamlit
#
# ###### Streamlit is an open- source app framework for machine learning and Data Science projects. It provides  you a create beautiful web applications for  your machine learning

# %%
pip install streamlit
# Out:
# ...
#
# ...
#    ---------------------------------------- 0.0/8.6 MB ? eta -:--:--
#    ---------------- ----------------------- 3.7/8.6 MB 21.8 MB/s eta 0:00:01
#    --------------------- ------------------ 4.7/8.6 MB 12.1 MB/s eta 0:00:01
#    -------------------------- ------------- 5.8/8.6 MB 9.8 MB/s eta 0:00:01
#    ------------------------------- -------- 6.8/8.6 MB 8.3 MB/s eta 0:00:01
#    -------------------------------- ------- 7.1/8.6 MB 7.2 MB/s eta 0:00:01
#    ----------------------------------- ---- 7.6/8.6 MB 6.0 MB/s eta 0:00:01
#    ------------------------------------- -- 8.1/8.6 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------- 8.6/8.6 MB 5.1 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/731.2 kB ? eta -:--:--
#    ---------------------------- ----------- 524.3/731.2 kB 3.7 MB/s eta 0:00:01
#    ---------------------------------------- 731.2/731.2 kB 3.3 MB/s eta 0:00:00
# ...
